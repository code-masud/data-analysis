# %%
import sys
import os
from scripts import SalesData

file_path = os.path.abspath('../data/raw/Walmart_Sales.csv')
os.path.exists(file_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 import sys
#       2 import os
# ----> 3 from scripts import SalesData
#       5 file_path = os.path.abspath('../data/raw/Walmart_Sales.csv')
#       6 os.path.exists(file_path)
#
# ImportError: cannot import name 'SalesData' from 'scripts' (unknown location)
